# %%
import random

# %%
class DummyLLM:
    def __init__(self):
        print("LLM has created")

    def predict(self, prompt):

        response_list = [
            "Old Dhaka biriyani is the best",
            "Tony Stark made jarvis",
            "I can be something else"
        ]

        return {'response': random.choice(response_list)}

# %%
llm = DummyLLM()
# Out:
# LLM has created

# %%
llm.predict('Say something')
# Out:
# {'response': 'Tony Stark made jarvis'}

# %%
class DummyPromptTemplate:

    def __init__(self, template, input_variables):
        self.template = template
        self.input_variables = input_variables

    def format(self, input_dict):
        return self.template.format(**input_dict)

# %%
template = DummyPromptTemplate(
    template='Write a peom about {topic}',
    input_variables=['topic']
)

# %%
template.format({'topic':'Bangladesh'})
# Out:
# 'Write a peom about Bangladesh'
