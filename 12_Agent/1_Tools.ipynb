# %%
from langchain_community.tools import DuckDuckGoSearchRun

search_tool = DuckDuckGoSearchRun()

result = search_tool.invoke('laliga news')

print(result)
# Out:
# Enter and discover the news about players, clubs, transfers and all kinds of news related to LALIGA competitions. All the information of LALIGA EA SPORTS, LALIGA HYPERMOTION, and Liga F Moeve: schedules, results, standings, news, statistics, and much more Follow all the latest LaLiga news, live results, schedule updates, player news, analysis, highlights and exclusive coverage on MARCA English. /> <meta name= Spanish Football News, La Liga News, Spanish Transfer News andall the latest information from all the top clubs, including Barcelona& Real Madrid Latest Spanish football news in English — La Liga, clubs, match analysis, and transfers.

# %%
from langchain_community.tools import ShellTool

shell_tool = ShellTool()

result = shell_tool.invoke('ls')

print(result)
# Out:
# C:\Users\ahamu\AppData\Local\Temp\ipykernel_26604\2727444312.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.tools import ShellTool
# Executing command:
#  ls
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
# c:\Work\Practice\Generative-Ai-with-LangChain\.venv\lib\site-packages\langchain_community\tools\shell\tool.py:33: UserWarning: The shell tool has no safeguards by default. Use at your own risk.
#   warnings.warn(
